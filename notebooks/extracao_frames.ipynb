# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import tensorflow

# %%
def extract_frames(video_path, output_dir):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    while True:
        ret, frame = cap.read()

        if not ret:
            break

        frame_count += 1
        frame_filename = os.path.join(output_dir, f'frame_{frame_count:04d}.jpg')
        print(f'Saving frame: {frame_filename}')
        cv2.imwrite(frame_filename, frame)

    cap.release()

# %%
video_filename = 'rap_apolo_sol.mp4' # substitua pelo seu vídeo

# %%
working_dir = os.getcwd()
root_folder = os.path.dirname(working_dir)
datasets_folder = os.path.join(root_folder, 'datasets')
videos_folder = os.path.join(datasets_folder, 'videos')
video_path = os.path.join(videos_folder, video_filename)
video_path
# Out:
# 'd:\\Users\\Eduardo\\Documents\\Infnet eletiva\\datasets\\videos\\teste1.mp4'

# %%
output_dir = 'frames'  # Diretório onde os frames serão salvos
if video_path:
    extract_frames(video_path, output_dir)
else:
    print('não encontrado')

print(f'Frames extraídos e salvos em {output_dir}.')
# Out:
# Saving frame: frames\frame_0001.jpg
# Saving frame: frames\frame_0002.jpg
# Saving frame: frames\frame_0003.jpg
# Saving frame: frames\frame_0004.jpg
# Saving frame: frames\frame_0005.jpg
# Saving frame: frames\frame_0006.jpg
# Saving frame: frames\frame_0007.jpg
# Saving frame: frames\frame_0008.jpg
# Saving frame: frames\frame_0009.jpg
# Saving frame: frames\frame_0010.jpg
# Saving frame: frames\frame_0011.jpg
# Saving frame: frames\frame_0012.jpg
# Saving frame: frames\frame_0013.jpg
# Saving frame: frames\frame_0014.jpg
# Saving frame: frames\frame_0015.jpg
# Saving frame: frames\frame_0016.jpg
# Saving frame: frames\frame_0017.jpg
# Saving frame: frames\frame_0018.jpg
# Saving frame: frames\frame_0019.jpg
# Saving frame: frames\frame_0020.jpg
# Saving frame: frames\frame_0021.jpg
# Saving frame: frames\frame_0022.jpg
# Saving frame: frames\frame_0023.jpg
# Saving frame: frames\frame_0024.jpg
# Saving frame: frames\frame_0025.jpg
# Saving frame: frames\frame_0026.jpg
# ...
